# %% [markdown]
# # Baktash Ansari
#
# Advantages and disadvantages of each model are written at the end of the notebook.

# %%
import torch
import re
import pandas as pd 
from sklearn.preprocessing import OneHotEncoder
import numpy as np
import math
from gensim.models import Word2Vec

# %%
cos = torch.nn.CosineSimilarity(dim=0, eps=1e-6)

# %%
def find_k_nearest_neighbors(word, embedding_dict, k):
  words_cosine_similarity = dict()
  for token in embedding_dict.keys():
    words_cosine_similarity[token] = cos(embedding_dict[word], embedding_dict[token]).item()
  words_cosine_similarity = dict(sorted(words_cosine_similarity.items(), key=lambda item: item[1]))
  return list(words_cosine_similarity.keys())[-k:][::-1]

def delete_hashtag_usernames(text):
  try:
    result = []
    for word in text.split():
      if word[0] not in ['@', '#']:
        result.append(word)
    return ' '.join(result)
  except:
    return ''

def delete_url(text):
  text = re.sub(r'http\S+', '', text)
  return text

def delete_trash(text) :
  text = re.sub(r'\u200c','',text)
  return text

# %%
word = 'زندگی'
k = 10

# %% [markdown]
# # 0. Data preprocessing

# %%
# !pip install json-lines
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: json-lines in /usr/local/lib/python3.8/dist-packages (0.5.0)
# Requirement already satisfied: six in /usr/local/lib/python3.8/dist-packages (from json-lines) (1.15.0)

# %%
import json_lines

# %%
# 1. extract all tweets from files and save them in memory base on each year.
# 2. remove urls, hashtags and usernames.

frame =  pd.read_csv("/content/mahsa_amini_data.csv")

frame.Text

result = []

for text in frame.Text :
  new_text = delete_hashtag_usernames(text)
  new_text = delete_url(new_text)
  new_text = delete_trash(new_text)
  result.append(new_text)

result
# Out:
# ['بنشین تا شود نقش فال ما نقش هم فردا شدن',
#  'این گوزو رو کی گردن میگیره؟؟ دچار زوال عقل شده از بس پای منبر دستمال کشی کرده.',
#  'برای ایران، برای مهسا.',
#  'مرگ بر دیکتاتور',
#  'نذاریم خونشون پایمال شه...',
#  'مابهت افتخار میکنیم نبات باعث شدی کل دنیا مارو ببینه',
#  'برای انسانای خوشگلمون',
#  'فارغ از هر باوری متحد شویم.',
#  'اینها عجب موجودات پستی هستن🥺🥺🥺الهی بگردم، من خودم باردارم و حتی توتظاهرات مسالمت امیز خارج ایران استرس داشتم ادم ها نا خود اگاه بهم ضربه بزنن،بمیرم برای دل اون زن که چه کشیده...مرگ بر دیکتاتور',
#  'کصخلا چرا ۴ تاوفحشش نمیدن؟',
#  'و از روی پول ملی....',
#  'برای آزادی ایران تا آخرین قطره خونم میجنگم 🇮🇷✌🏻 (7) ',
#  'داریم چهل تا میشیم',
#  'سی و سه',
#  'سلام بچه ها اگر من رو میبینید حتما هشتگ بزنید.',
#  'امروز برای کاری رفتم سراغ وسایل قدیمی و اینارو دیدم : برای تمام روزهایی که رفتم دکه تا کارت دیال آپ بخرم و یه چیزایی تو وبلاگم بنویسم و 88 زدید آرشیوم و حذف کردید برای اون روزها خیلی بغض دارم. ',
#  'فالو کنید بک بدم',
#  'زن،زندگی،آزادی.',
#  'دستاشو مشت کرده✊',
#  'بچه ها را تا سرنگونی رژیم به مدرسه نفرستید. روس جنایتکار به دست عمله های سپاهی و بسیجی، عزیزان شما را پرپر میکند. با حماقت خود هواپیماهای اوکراینی نشوید!',
#  'زنده باد زنده باد زنده باد',
#  'هنوز خیلی کاردارن برای شاه فورا گوادلوپ جلسه گذاشتن',
#  'جایگزین واتساپ و تلگرام ',
#  'بچها کراشم کراشم بچها',
#  'پنج',
#  'قبلی یادم رفت یچی بنویسم',
#  'مامانم منم همینطوره',
#  'هدا رستمی چی؟ خفخون گرفته یا دیکتیو کرده؟',
#  'پاینده ایران زنده باد آزادی جاوید شاه',
#  'بوق هایتان مستدام باد این هم شکلی از مبارزه است',
#  'مگس در دهنشون و لای ریشاشون بچه کرده🤢🤮#مهسا_امينی',
#  'داداش منم ریدم همیشه فرصت هست واسه قبولی نگران نباش. باهم دوباره امتحان میکنیم.',
#  'به امید روزی که با خوشحالی هم رو به آغوش بکشیم',
#  'این فیلتر شکننصب کنید نامکابری و...بزنید وقتی وارد برنامه شدید Windscribe پرچمکشورا رو میاره بزنید اولین آمریکا بعد چن گزینه اولی رو بزنید اینستا و توییتر .... میاره',
#  'نمیفهمم چرا مردم یکبار دسته جمعی بیرون نمیان تو خونه نشتین تلویزیون باز میکنین وای جوانان ما دارن پر پر میشن اگه یکبار برا همیشه همه باهم بیرون بیاییم میتونیم تو چند روز کارشون تموم کنیم',
#  'اخرین هشتکای امشبم',
#  'برای',
#  'یدونه',
#  'کردها مثل بوته شِنگ میمانند؛هرچه درو کنی فردا دوباره سبز میشوند. کردها قرنهاست با سر بریده آواز میخوانند.',
#  'یزد با حدود ۱۰ مجروه سپاهی ',
#  'مزدور ی که در سفارت ایران در آلمان کار می کنه. پلیس اسکورتش کرد متاسفانه. بیشرف بیشرف. ',
#  'باشد که ...',
#  'بیاید اکشب جای هرکس که نت نداره توییت بزنیم باید بفهمن با قطع کردن نت هم نمیتونن جلومونو بگیرن\U0001f90c🏻',
#  'برای خاکی که خون عزیزامون روش پاشیده شده:)🖤 65',
#  'برای ازادی که یک کلمه که میدان نباشه',
#  'بیناموسها چرا به کردستان حمله میکنید مادر حرومیهای ننهکیردزد',
#  'برای از دست دادن هموطن هامون 🖤',
#  'دویست و چهار',
#  'قیافشو اخه همه خائنای کثافت قیافشون اینه🤮یعنی خودشون میدونن قیافه هاشون اینه؟💩🤔',
#  'فرودگاه ها رو بگیرید تا فلج بشن ! همونطور که برای جنگ سوریه و عراق نیروی ایرانی و افغان می فرستادن بعنوان مزدور برای ده میلیون بجنگن/حالا هم از عراق و سوریه نیرو میارن برای سرکوب ما! نذارید نیرو وارد کنن!',
#  'ببینید مزدوران نجس جمهوری اسلامی چطور بدون مجوز وارد خونه میشن! ',
#  '۹۸ ام همین شد تعطیل کردن وسط اعتراضات گفتن هوا آلودس😂',
#  'آخه کم خون ریخته،فرصت بیشتر لازم داره ضحاک😡',
#  'از هشتگ زدن دست برنداریددد',
#  'یازده',
#  'یک',
#  'تا سبز شدن کل ایران میجنگیم',
#  'برای انانیمس بچه ها این هشتگ مهسا برام الان میزنه ترندیگ درسته یا نه؟؟',
#  'ساعت ۵ نت رو کلا قطع میکنن تا میتونین رو ترند کنید',
#  'هشتک کافی نیست من در خیابان وقایع را دنبال خواهم کرد',
#  'من بگردم واسه بچه های کلاس اول و دومی که به زور مقنعه گذاشتن این همه سال:) مقنعه های کج:) موهای فرفری:) بگردمشون الهی',
#  'برای اون زمان که میگفتید و امااا حقیقت ماجرا و ما باور میکردیم',
#  'چهار',
#  'ما دنبال حقمونیم دست به دست تا سرنگونی',
#  'سلام منو برسون به و',
#  'یک',
#  'در برابر جنایت جمهوری جنایتکار اسلامی ساکت ننشینیم',
#  'برای مهسا',
#  'چربش کن خایمنه ای',
#  'اگه تک افتادین و حمله کردن بگیرنتون اون چند ثانیه طلایی رو از دست ندین به اونا التماس نکنین که ولتون کنن، فقط جیغ و داد کنین و درخواست کمک کنید، بدنتون رو شل کنین بشینین روی زمین. خیلی دیدیم اینشکلی که پسرا ریختن ازادشون کردن.',
#  'برای ایرانم برای وطنم',
#  'بعدها این دردا رو قاب میکنیم میزنیم به دیوار اتاقامون بعدها این قاب ها رو به نسل بعدی نشون میدیم میگیم ببینین ما درد کشیدیم تا شما درد نکشین',
#  'باید خیلی بشع',
#  'همه بشمارید شیش',
#  'برای جونامون که قبله ی شجاعتن',
#  'ادامه میدیم',
#  'برای همه گریه های تو فرودگاها',
#  'فراموش نکنیم که ما خواهان ایرانی یکپارچه با حکومت دموکرات هستیم. اگر هرگونه حکومت اقتدارگرا مثل سلطنت، بعد از این خونهایی که ریخته شد بر سر کار بیاد، به معنی بینتیجه بودن این تغییرات هست.',
#  'مهسا',
#  'از اینکه همه مشکلات کشور تقصییر دشمنه فقط میشه یه نتیجه گرفت : کشور دست دشمنه.',
#  'تا باشه از این مشت و لگداااا باشه',
#  'صدوسیههه',
#  'این اگه راست باشه خیلی حرفه. کسی خبر موثقی داره ازش؟',
#  'افتخار میکنم به هم جنسام🖤#Mahsa_Amini',
#  'برای پدرم برای پدرم برای پدرم',
#  'ملکه انگلیس مُرد عینِ یه چُس سریییع استوری گذاشتی RIP الان لالی ؟ تو ایران دارن جون میدن تو اینور آب از چی میترسی بُزدلی که جز چسی و خودنمایی کار دیگه ای بلد نیستی! من تک تکتونو یادم میمونه.',
#  'تو هشتگ ها هم گه گیجه گرفتم.. تو انتخاب ترندینگش برام نمیاد و احساس میکنم موازیه تو هم در واقع با آندرلاین ترند شده ولی تو ترندینگ اسرائیل به تنهایی 2میلیون توییت بدون آندرلاین وجود داره ',
#  'برای ایران 💔🖤',
#  'ما بیشماااریییم بیشمااااریم',
#  'فیسبوک و متا با جمهوری کثیف اسلامی هستن تروخدا تروخدا ریتوییت کنید همه بفهمن از واتساپ و اینستا استفاده نکنن هر چی بفرستید رو رصد میکنن میفروشن به دولت. اگه اینترنتتون وی پی ان باز میکنه از تلگرام استفاده کنین اگه نیاز داشتین. ما میتونیم🖤',
#  'پنجاه و شش',
#  'با هم 🖤',
#  'دم اینا رو بگیری کس و کارشون یک جا وصله دیدم که میگم',
#  'منم ندارم اما حسابه خیالت راحت...😘😘🌺 بیا همو فالو کنیم😉',
#  'یا الان یا هرگز',
#  'برای همه جوونهایی که دلشون میخواد ازدواج کنن و تشکیل خانواده بدن ولی پولشو ندارن',
#  'هوی تو عرزشی/سایبری هستی؟ ',
#  'هر وقت یادم میاد این پدسگ پاورپوینت درست کرده بود واسه ساپورت و مانتو، دلم میخواد هرچی دم دستمه بهش فرو کنم حرومزاده رو',
#  'برای',
#  'بیست و چهار',
#  'خانه سرخ و کوچه سرخ و خیابان سرخ است',
#  'برای نخبه های پناهنده شده',
#  'برای گایش اون وزیر جاکش به همراه تمام خانوادش به مدت یک هفته به صورت روغنی🗿',
#  'ها ای که گفتی من نمیدونم چی بیدش',
#  'زن زندگی آزادی🕊️1 Please our voice',
#  'برای مهسا',
#  'روش دیگه : توی ستینگ گوشیتون میتونید توی قسمت text replacement تنظیماتشو اینجوری بذارید که تایپ کنید مثلا این ))) مینویسه',
#  'فراموشت نمیکنیم🖤',
#  'بخاطر تمام بدبختی هایی که تو ایران کشیدم چون نمیخواستم با قانون تخمی ایران ازدواج کنم.',
#  'تا آزادی که بسیار نزدیک است',
#  'مهم اینه مثل این جنده نیستیم',
#  'کمک دوار بازی ایران زنه 🤣 شب سختی در انتظار سانسور چیه🤣',
#  'اره خیلی باحال میشه😭',
#  'صد و چهل و یک',
#  'من ریدم تو اون ویروسی که بدموقعه وارد بدن من میشه پدرسگ من الان باید وسط خیابون میبودم 😡',
#  'شرف ندارن به عزای تک تک عزیزاش بشینه',
#  'وقتی خیابون جا مردم شده پره پلیس انقلاب میشه تنها میانبر گریز ..',
#  'شما در دو جهت میتونی به شکل افقی و عمودی',
#  'بیماری زمینه ای داشته و در بچگی عمل حراجی',
#  'بسلامت برمیگردی',
#  'لطفا اطلاع رسانی کنید',
#  'اردبیل ۲۳ مهر ۱۴۰۱ کتک خوردن یک بسیجی از مردم ',
#  'زنده باد کردستان...',
#  'تو روزای عادی هرچی کیر پرت میکنی اخونده که میپره با دندون میگیره تو ببین این روزا یکیشون تخم میکنه نفس بکشه؟ سوراخ موشا رو بگردید بەرخودان ژیانە✌🏻',
#  'ما هستیم:)',
#  'برای آنانیموس که شونه به شونمون داره میجنگه برای خواهرم',
#  'برای ایران',
#  'برای اینکه رسم ماست، ایستاده مردن.',
#  'برای',
#  'ایرانو پس میگیریم',
#  'چون حس تنفر رو شما به ما یاد دادید. متنفرم. متنفرم. متنفرم.',
#  'برای نویسندگان و شخصیت های سیاسی کشته شده در قتل های زنجیره ای دهه ۷۰',
#  'ما معترضیم نه اغتشاشگر.',
#  'یه حس دوستی قشنگی میبینم بین اونایی که حتی اسمشونم نمیدونم',
#  'منم همینطور اولین بارا این همه هشتگ میزنم',
#  'اهای اکراین پهبادهایی که به شما حمله کرده ایرانی نیست، جمهوری اسلامیه، ایرانی ماییم، مقتدر، آرمانخواه، آزاده ،انسان انسان انسان',
#  'برای خواهرم',
#  'من صد شدم بچه ها هر کسی کم داره پاشه بگه فالو کنم هوای همدیکه رو داشته باشین',
#  'حجم تيرندازى در شهرستانها به مراتب بيشتر از تهران است تهران توچشمه مى ترسن زياد بكشند صداى شهرستانهاباشيم',
#  'بخاطر چشایی ک دوباره مجبور شدم عینک بزنم:)',
#  'تیر مستقیم میزنن حروم زاده ها',
#  'چقدر هممون شبیه ی خانواده شدیم :)))\U0001fac2💜',
#  'برای ایرانم🖤',
#  'میگه اسپری فلفل جرمِ ، خواهر گلم کلا اغتشاشات یه فایل مخصوص داره دیگه شما رو اونجا بگیرن بای دیفالت مجرمی چه با اسپری فلفل چه بدون اون ... پس یه چی همراهتون باشه برای دفاع از خودتون',
#  'بچه ها یه هُلی بدید به ۱۰۰ برسم بک میدم دمتون گرم\U0001fac2',
#  'دو',
#  'واقعن متاسفم براشون!',
#  'وااای وااای از اون صبح لعنتی',
#  'برای مهسا (شصت و سه)',
#  'برای اینکه جلو بچهای ایندمم برای اینکه کاری نکردم تا زندگیشون بهتر بشه شرمنده نباشم',
#  '«این همه سال جنایت، مرگ بر این ولایت» شنبه ۱۶ مهرماه ۱۴۰۱ ',
#  'برای ایران آزاد',
#  'هاها',
#  'و راستی تولدت مبارک:)))',
#  'منظورشون همون پسرایی که خودشون و میندازن جلو ضربات تا خدایی نکرده به دخترا نخوره؟ کثافت بزنه به اون مغز نجستون اخه',
#  'دشمنان ما از تمام توانشون در مقابل ما ايستاده اند و اكنون با حيله هاي كثيف تفرقه افكني در حال سمپاشي هستند، فريب اين تبهكاران را نخوريم.',
#  'اگه همه ی تیم ها همینجوری عمل کنند نمیتونن ببرنشون بازداشتگاه',
#  'ریدم دهنت که بیشتر متوجه بددهنی ما بشی .رهبر جاکشتم تیکه تیکه میکنیم که بیشتر حجم خشونت ما رو ببینی ✌🏻',
#  'جدی به کمکتون نیاز دارم میشه ریت کنین فالورام بیشتر بشه هشتگام حساب بشه؟ بکم میدم به همه.',
#  'هشت',
#  'برای وطنم',
#  'خوانندهی آهنگ another love تام ادل، یکی از کنسرتهاش رو تقدیم ایرانمون کرده =) ',
#  'بی شرف های مزدور',
#  '۶۴. برای 64. For',
#  'برای تمام زنان ایران',
#  'این جونهایی که گرفتن بی جواب نمیمونه',
#  'برای روزگاری که جز نام آزادی ((تَکرار)) نمی کنیم.✌',
#  'برای تمام سالهایی که به حای خدمت کردن مردم رو با هم دشمن کردن، اعتماد رو از بین بردن، تخم نفاق پاشیدن و اخر سر هم شکست خوردن',
#  'برای آزادیمون🖤',
#  'به امید آزادی و رسیدن به حقمون',
#  'برای آزادی خودمون صدامون به گوش همه برسه',
#  'بیشترین فشار روحی وقتی به انسان میاد که میبینی عده ایی کشته می شن، تا ما زندگی آزاد و شایسته ایی داشته باشیم هموطن سهم خودت رو، در حد توانت، به آینده بهترمون بپرداز',
#  'بمیرم واقعا مادر بودن تو ایران سخته 🖤🖤🖤😔😔😔😔',
#  'تصویر اگر زیبا نبود نقاش خوبی نیستی از نو دوباره رسم کن تصویر را باور نکن خالق تو را شاد آفرید آزاد آزاد آفرید پرواز کن تا آرزو زنجیر را باور نکن (به امید آزادی ...)',
#  'بیا اینو بدم دستت',
#  'برای آزادی هایمان...',
#  'خون جوانان وطن',
#  'برو پشت میکروفون یه آهنگ وحشی بخون بزار یه صدا برای فریاد همصدا داشته باشیم.',
#  'برای ایران',
#  'خامنه ای با ترند کردن سلام فرمانده به دهه نودیا گفت سلام علیکم ✋ دهه نودیا هم با گفتن مرگ بر دیکتاتور پاسخ دادن علیکم السلام 👋 . . . نتیجه اخلاقی: به پایان سلام کن دیکتاتور ✌️',
#  'عزیزان در کنار هشتگ مهسا، هشتگ هم ترند کنید. ملت نرن سر کار جا از پا میفته. این تنها راهه ،بدون اینکه حتا کشته بدیم. یه هفتهای عمر ضحاک خاورمیانه تموم میشه.',
#  'برای',
#  'برای مادر جهانبانی ',
#  'قهرمان واقعی.معنی آزادی.به خاطر آزادی',
#  '🔺 مهدویکیا: نمیشود فرزاندان خودتان آنسوی دنیا در رفاه باشند و از مردم بخواهید نان خشک بخورند مرسی مرد بزرگ با رسانه ای که داری حمایت میکنی ',
#  'هیچ ایرانی وجود نداره که وقتی بخواهد آنچه را در ایران میگذرد را بیان کند، بغض در صدایش نداشته باشد.',
#  'واقعا نباید کوتاه اومد',
#  '🖤 آزادی 🖤',
#  'ده',
#  'اینترنت رو قطع کردن ،نیروانتظامی ولباس شخصی ، دوربین شهری ها ناکارشد ،هایلوکس ها اتیش گرفت یه سری عزیزان هم باماشین ترافیک ایجاد میکردن درمجموع برای شروع خیلی عالی بود',
#  'پیروزی پیروزی',
#  'روزم با جواب این مرد ساخته شد',
#  'بچه ها کامنت بذارین همدیگرو فالو کنیم اگ ی درصد اون مطلب ک باید فالوورامون بالا باشه تا توئیتا حساب شه درست باشه کفکر نمیکنم درست باشه بازم کامنت بذارین از تو کامنتا همو فالو کنیم',
#  'این دفعه فرق داره :)',
#  'برای منصرف شدن از اقدام به بارداری در این ماه که بعد از پنج سال زندگی مشترک با همسرم تصمیمشو گرفتیم …',
#  'من واقعن دیگه نمیکشم، بیشرف بیشرف بیشرف شما از کجا اومدید آخه😭😭😭',
#  'برای اینکه دائما یکسان نباشد حال دوران ۸۳',
#  'برای رهایی',
#  'واسه همه پسرامون که کل جوونیشون استرس سربازی دارن',
#  'همین ۲',
#  'ای ول ربات ✌️✊✋ برای تمام ربات های تویتر برای برای ایران آزاد برای',
#  'برای آینده',
#  'برای هرروز و هرلحظه و هرثانیه ناامید بودن',
#  'دمتون گرم خسته نباشید توروخدا ماسک بزنید',
#  'که یه چیزی گفته باشم',
#  'جای خانوادم',
#  'علت اینکه تا الان به این جدیت انقلاب نمیشد بخاطر این بود نسل قدیم انقلاب کرده دیگه خسته است و دیگه جرئت تکرار را ندارد و چند نسل بگذرد تا انقلاب کند، ',
#  'دور از جونت قشنگم مرتقب خودت باش',
#  'متاسفم که واقعا اینو خوندم',
#  'ما هستیم',
#  'واقعا وقتی اینو دیدم خستگیم در رفت',
#  'ها فراموش نمیشوید بعدا باهاتون کار داریم',
#  'ترنده دیگه عه',
#  'برای تمام لحظه هایی پلیس دیدیم و از ترس راهمون رو کج کردیم جای این که اعتماد کنیم',
#  'و مجازی شدن کلاس های دانشگاه علامه طباطبایی ',
#  'برای تمام دروغهایی که در کتابهای تاریخمان نوشتید',
#  'ماشالله بیش باد',
#  'برای اهواز',
#  'صرفا برای خالی نبودن متن',
#  'دیگه ه خبر؟',
#  'قمارباز نگه به تخمم سکته میکنه🤣🤣 کسخلا',
#  'برای آزادی...',
#  'همه با هم برای ایران، فردا بیرون میآییم تا فردا های بهتری داشته باشیم. ',
#  'نکشیمون خانم مارپل.',
#  'برای مهسای ایران🖤',
#  'تا آخرین لحظه ای که وصلین هشتگ بزنید',
#  'دوشنبه ۰۲ آبان ۱۴۰۱ سی و نهمین روز قیام سراسری مردم ایران برای آزادی شیراز تجمع پزشکان در شیراز دقایقی پس از این ویدیو مامورها به این تجمع حمله کرده و به سوی معترضین تیراندازی کردند ',
#  'اینجا باید امریک رو هم اضافه کرد ',
#  'توهم زایی مواد مخدری که میزنن، مافوق صوت و تصویره! والتروایت سازه فکر کنم!🤡 ',
#  'همین الان تو جلسه با نماینده پارلمان و وزیر دولت کانادام و ازش حمایت میخوام. کاریه که ازم بر میاد.🇨🇦#مهسا_امینی',
#  'برای ',
#  'اخیش دلم خنک شد',
#  'هشت',
#  "ایران را فراموش نکنید. Don't forget IRAN",
#  'شروین بازداشت شد من هم به علت موزیک سیاسی ۱۹ ضربه شلاق بریدن برام فقط برای اینکه آزادی بیان نیست حیف هنرمندان مملکت',
#  'برای اون کسخلایی که هشتگای موازی ترند میکنن',
#  'حسین ماهینی بازداشت شد. ریدم سر در جمهوری اسلامی.',
#  'عدل علی شون اینه ؟؟؟؟؟',
#  'واقعا چطور به خودشون جرعت میدن(:؟💔',
#  'دو تا بش میگفتن خب',
#  'درباره دهه هشتادیا بد گفتین قبول ولی الان همونا بیشتر همه حواسشون به ناموسشون هست❤️\u200d🩹🤝',
#  'مراقب باشین دوباره هشتگ اشتباه داره ترند میشه دو تا آندرلاین (_) نداره فقط یکی',
#  'کاربران مشغول کارند',
#  'شجاعت مردم مثال زدنيه',
#  'صد و پنجاه و ششمیش',
#  'برای اتحاد',
#  'تا حالا دیدید کسی تو دعواهای مجازی ب جایی برسه؟ پس حواشی رو بذارید کنار رو هدف متمرکز شید',
#  'برای تحقیرای سر صف شیش صب',
#  'داداش رپرا زر میزنن طهران واس توعه',
#  'در خونه هاتونو باز بزارید',
#  'مهسا دختر ايران تنها نيست',
#  'دیگه نکتهای نداره پرایویت باشم',
#  'طاقت بیار رفیق داریم میرسیم',
#  'پنج',
#  'برای ایران برای عدالت زن ،زندگی ،آزادی',
#  'حق دارین خسته بشین اما الان وقتش نیست',
#  'آزادی در همین نزدیکی',
#  'برای آزادی',
#  'طوری ها می گویند «گشت ارشاد بهانه است» که انگار در دیگر زمینه های زندگی، هم سطح اتحادیه اروپا در حرکت هستیم. ',
#  'بزنید هشتگوو',
#  'برای مهسا 🖤 هرگز فراموش نخواهی شد🖤🖤 ریت یادتون نره 🙏🏼 ',
#  'برای تمام روزایی ک مجبور شدیم مقنعه بپوشیم شلوار گشاد و مانتو تا زیر زانو بپوشیم ب خاطر مدرسه های لعنتیتون',
#  'برای بهبود و پیشرفت',
#  'برای همه اونایی که بخاطر واکسن نداشتن از دست دادیم',
#  'این زیر اینو هشتگ کن …',
#  'خواهشا تو این اوضاع همو فالو کنید که دیده شه هشتکا:)🖤',
#  'خوش اومدی',
#  'تا چند وقت پیش ما ب زور هزار تا قرص و تراپی خودمون سرپا نگه داشته بودیم اما حالا با این حجم از جنایت و کثافتی ک دیدیم دیگ هیچوقت ی ادم معمولی نمیشیم...',
#  'آخرین تلاش صدا و سیما برای جذب مخاطب استفاده از توییتای هیچکسه:/',
#  'به احترامشون..',
#  'بعضی از سلبریتی ها دو پهلو موضع گیری میکنند که باعث شده مردم آنها را شناسایی کنند',
#  'برای آزادی',
#  'هوووووووو چه حالی داره',
#  'نه',
#  'صدای و باشیم',
#  'برای انتقام',
#  'چهارصد و سی و شیش',
#  'کاش میدید ون های گشت ارشادی که بردنش دارن آتیش میگیرن',
#  'یکشنبه ۳ مهر ۱۴۰۱ نترسید نترسید ما همه باهم هستیم «آخوند نرود/ ایران میرود» ',
#  'هفتاد سه',
#  'زنان نیمی از جامعه رو تشکیل میدهند و نیمی دیگر رو به دنیا میارن پس برای همه',
#  'برای ۲ تا نوجوان ۱۶ و ۱۸ ساله زنجانی که دیروز کشته شدن',
#  'هر چه تبر زدی مرا، زخم نشد جوانه شد ...',
#  'دوس دارم از سلامتی چندتا از کاربرا بپرسم ولی نمیخوام اسمشونو بیارم و نمیدونم از کی بپرسم.',
#  'هشتگ خالی نزن :)',
#  'برای قطعی آب و برق تو اوج تابستون!',
#  'برای دیدن :(ایران آزاد شد)',
#  'قربون تک تک پسرامون برم که انقد شجاعن🥺❤',
#  'اونجایی که هیچکس تو تو کجا بودی میگه: تصمیم/تمرکز/تغییر/اخطار/سرکوب/تردید/مقاومت/انفجار رو باید این روزا سرلوحه بکنیم',
#  'ترفندهای مزدورا رژیم',
#  'معلومه از ترس ازدرب پارکینگ دررفتی',
#  'برای اون جوونی که داره از تیراندازی مستقیم مامور سپاه ج.ا فیلم میگیره و همزمان به مامانش تاکید میکنه مامان حالم خوبه!!! .',
#  '🛑نشر واجب🛑 کسانی که دیروز مردم انزلی رو سر حد مرگ میزدند و میکشتند. باید شناسایی بشن مادرشون به عزا شون بشینه. ای ',
#  'هستیم هنوزم',
#  'بچهها با این اپ میتونین پیامهاتونو رمزگذاری و رمزگشایی کنین که اگه مجبور شدین با مسیج یا ایمیل با هم حرف بزنین به پیاماتون دسترسی نداشته باشن. قبلش با دوستتون یه رمز طولانی و امن انتخاب کنین، اینو توی پسوورد بذارین ',
#  'چرا برای اعتراضات یه جای ثابت نیست که همه متحد بشند؟؟؟؟',
#  'ساختش اسونه . فراموسش نکنین همین سلاح ساده هم میتونه در دفاع هم درحمله ازش استفاده کرد پسدست کم نگیرین .دمتون گرم .لطفا بهم دیگه توصیه کنین حتما همراه داسته باشن',
#  'یک مرد دیگه؟ آخونده رو هم مرد حساب کردی؟ 😂',
#  'برای خواهرم مهسا',
#  'این پروژه سپاه است برای درگیر کردن احزاب کرد در جنگ مسلحانه. اب به اسیاب سپاه نریزید. سپاه به این بهانه دست به قتل عام کردها می زند.',
#  '*اعلام حضور کردن ولی خدایی یه هل ریزی بدید منو برسم به صد هر چند نمیدونم چرا باید برسم به صد ولی تا جایی که فهمیدم باید برسم به صد.',
#  'قهرمان واقعی،معنی آزادی،به خاطر آزادی',
#  'او از بچگی بیماری خو شهیدی داشت',
#  'نام تو نماد شد تمام',
#  'جشن وحدته!!! جشن وحدتههعععععههههه!',
#  'میدان شقایق (خاقانی) امشب پر از یگان ویژه بود. دور میزدم و یک به یک خیره میشدم به چشمشون آخر پرسیدم. آیا شما ایرانی هستین و اسلحه و باتوم بروی مردم میگیرید؟',
#  'این وسط امیرحسینو یادتون نره:)',
#  'یه ایده باحال دیگ اینه ک جوری حرف بزنیم انگار هم خونه ایم &gt;&gt;&gt;&gt;',
#  'برای دریای خزر که آن را به روسیه و کشورهای دیگر فروختید تا شکم حرام خوارتان را پرتر کنید .',
#  'یس همینههههه',
#  'بازداشت خبرنگاران و سلبریتیها و معترضین نه تنها فایدهای ندارد بلکه گروههای مخالف را بیشتر و مصرتر خواهر کرد',
#  'مرگ بر ستمگر چه شاه باشه چه رهبر',
#  'رویای ما ... ',
#  'برای جوانی',
#  'باهمیم',
#  'گلشیفته آسون نیست اصلا هم قرار نبود آسون باشه تو دریایی که طوفانیه می شه ناخدای قهرمان شد. ✌️ مثبت وبا انرژی ادامه می دهیم ما همه با هم هستیم 🕊️☮️❤️\u200d🩹',
#  ' ما، تماشاکنان ویرانی! مات! غرق در بهت و حیرانی! ظهر، عصر، شب، سقوط و نزول باز صبح شد! سلام ایرانی!',
#  'خیلی از کسانی که باید کف خیابون همراهمون باشن منفعل نشستن تو خونه هاشون چون نمیدونن فردای براندازی قراره چه اتفاقی بیوفته. خواهش میکنم از اتحاد امروز برای ترسیم چهارچوب سیاسی و اجتماعی ایران فردا استفاده کنیم.لطفا ریتوییت کنید',
#  'آخوند خوب را باید او کشت که بد هاش بدونند گذشتی در کار نیشت .',
#  'الکی که بهش نمیگن جادوگر!',
#  ' برای وقتی که با اونی که دوستش داریم دست تو دست تو خیابون راه بریم...',
#  'آبجی مهسا اسم تو رمز شد',
#  'از قیام زنان بترسید. زن_زندگی_آزادی اتحاد-انقلاب ',
#  'در ایران هم مفعول های حکومتی توقع دارند،که هر گوهی خوردن کسی بهشون کاری نداشته باشه ولی کور خوندید.امیدوارم ایندفعه،سرِ افعی رو قطع کنیم. مرگ بر',
#  'ما هستیم',
#  'با تو',
#  'بچه های اروپا پاشین یه آخر هفته برین برلین برای خودتون، خانوادههاتون، و نسل های آیندهاتون',
#  'برای ایران آزاد',
#  'به خاطر سجاد امیری که برای رها شدن از دردی که شما واسش ساختین تو سی سالگی خودسوزی کرد🖤 ',
#  'دقیقا همینطوره دیروز صادقیه ترافیک وحشتناکی بود به حدی که حتی موتور هم نمیتونستن بفرستن اما کلی نیرو از خط ویژه فرستادن',
#  'براي همه ما',
#  'دویست و هیفده',
#  'حواستون به اکانتایی که این چند روز به بهونه قطع بودن نت توییت نمیزدن الان یهویی اومدن توییت میزنن باشه مخصوصا به فالوور بالاهاشون دیگه خودتون بهتر میشناسیدشون',
#  'شایدم همه فهمیدن که سکوت برابر با مرگه',
#  'مادر به فدایت\U0001f979',
#  'یعنی از ترس ریده به خودش.',
#  'همه باهم در کنار هم وَطَنَم♡',
#  'ای من گاییدم مادر و پدر عرزشیارو که هشتگ شبیه ساختن بابا برا من ترندینگ بالا نمیاد چه گوهی بخورم',
#  'برای ایرانم',
#  'آزادی',
#  'چهار دهه در ۲۴ ثانیه به روایت تصویر ',
#  'سلام ،یه دستورکار اومده برا ارتش که سوگند وفاداری ارتش با ولایت تحت مراسمی در صبحگاه کلیه پایگاه های ارتش برگزار میکنند مثلا سوگند وفاداری به ولایت بخورند ،لطفا اطلاع رسانی کنید.',
#  'ده، هیچ وقت فکر نمیکردم یروزی مردم ایران انقدر قشنگ اتحاد پیدا کنن',
#  'یک',
#  'لطفا صدای باشیم',
#  'برای پاهایی که تن خسته مونو کشوندن و تونستن از گلوله و شوکر و باتوم نجاتمون بدن …',
#  'برای احمد نعیم آبادی',
#  'رباتای گرامی یه هشتگ مهمون نمیکنید مارو؟',
#  'مواظب باش شب سوم نزارن در کونت 🙂😂',
#  'تیر اخرو وقتی میزنین که رو اجرا کنید',
#  'چهار',
#  'گاد محافظو پناه بچهات که کف خیابونن باش ما پیروز این جنگیم',
#  'مینییی',
#  'براي ايران',
#  'به امید آزادی همه جا',
#  'والا اینجوری که اینا دارن از ترس کونشون فرار میکنن، تمام اعضای تیم فوتبال مجلس خبرگان لژیونر محسوب میشن',
#  'دیگه به یکماه نمیرسن کارشون تمومه',
#  'ده',
#  'برای ازادی .....',
#  'خیلی خوبه',
#  'برای آزادی۳۰',
#  'قربونتون که با وجود ترس و وحشت وقتی همراهی بقیه رو میبینید جون میگیرید و ادامه میدید.\U0001f979',
#  'برای اینکه مهساهای بعدی به وجود نیان دست نمیکشیم.',
#  'ارشاد واقعا دمت گرم. از آبان 98 که کنار مردم ایستادی و کار خبرنگاری بی طرف رو انجام دادی تا امروز دنبال میکنمت. واقعا درود بر تو. ما مردم ایران اینا رو یادمون نمیره',
#  'چون نباید داشته باشیم ...',
#  'خوشگله که جوین سپتمبر ۲۰۲۲ هستی فالو نکن',
#  'تو راهپیمایی عرزشیا شعار میدادن مهسا امینی بهانه اس هدف اصل نظام است واقعا تنها جایی بود که حرفمون یکی بود',
#  'برای عشق، برای زندگی، برای آزادی. برای ما.',
#  'برای زنان سرزمینم',
#  'صد در صد .',
#  'منو هشتگ و کون اخوند یسسس',
#  'توپ تانک فشفشه حاج آقای ما کیرکشه',
#  'هشتگ ترند کردن و ترند نگه داشتن لیدر می خواست؟ بقیه اش هم مثل همین.',
#  'برای ما برای مهساها...',
#  'برای خواهر کوچکترمان',
#  'برای استریپ تیز کردن خامنه ای، رییسی، اژه ای، و بقیه آخوندا و ارزشی ها دور میدون آزادی ✌🏻',
#  'هشتگ یادم رفت',
#  'برای نفسه تو سینه حبس شده برای حق های ناگرفته',
#  'دوستان من اینجا نیومدم نصیحتتون کنم ولی اگه تو این شرایط غیر قابل تحمّل یه پارتنر خوب دارید، واقعاً قدرش رو بدونید.',
#  '💖💖💖 ازادی ایران در افق دیده میشه نشستیم به عشق اون روز که دیگه دور نیستش در افق',
#  'برای مهسا',
#  'برای همه مادران و دختران ایران زمین',
#  'من اصلا فالوور ندارم هشتگ بزنم تاثیری نداره ولی باز همه جا هشتگ زدم',
#  'تظاهرات برلین در حمایت از مردم ایران ',
#  'زن،زندگی،آزادی',
#  'بسیار به ندرت جاکشتر یافت شده. زنده باد ایران',
#  'اره دشمنی همتون ، برید بیرون از کشور ایران . غاصب های بی ناموس ،',
#  'گه تو قیافش کاش مردم مسلح شن و ایناروتیکه تیکه کنن',
#  'برای ۱۵۰۰ نفر',
#  'یه جا خوندم نوشته بود برای دخترانی که به حکم اعدام یک شب قبلش بهشون تجاوز میشه چون اعدام برای دختران باکره نمیشه(: نمیدونم چی باید بگم .',
#  'ازتونم بچه میخوام که این ژن منتقل شه',
#  'دو',
#  'دقیقا همین طوره حتی سواد درست و حسابی هم ندارن دیگه چه برسه به شعور و شخصیت و فرهنگ',
#  'اينم دوميش',
#  'فردای اون روز! فکرشم قشنگه :)))',
#  'زن زندگی آزادی مرد میهن آبادی هشتادوهشت',
#  'ببین دیگه واسه حجاب نیستا از این جا میشه انتقام اونا که کشتی ، بزار زمین اون بی صاحابو',
#  'راستی',
#  'سه',
#  'از کنار هم بودن. بگیم از پیروزی از خورشید توروخدا. کمکمون کنین😭😭😭😭😭😭😭 بچه ها هشتگ و رو با هم بزنید چون گفتند حمایت کنید یا الان یا هیچوقت!',
#  'برای پدربزرگ هام که همین ارزوی مشترک رو داشتن',
#  'نمیدونم قضیشون چیه به منم پیام میدن:///',
#  'برای نام زیبای مادرم که تو هیچ فرمی ازم نپرسیدن...:)',
#  'یه مفت خوربه درک واصل شد ',
#  'Dona, vita, liberta زن، زندگی، آزادی دوستتون دارم.',
#  'منشنن',
#  'برای خواهر و برادران با شرفم',
#  'تمایل ب ویروسی؟؟؟؟',
#  'به نام زن زندگی آزادی',
#  'دختری که دیروز 30 شهریور توی نوشهر با تیر مستقیم حرومزاده های ج.آ شهید شد هفته ی بعد عروسیش بوده😭😭😭😭🖤 توروخدا نزارید فراموش بشن. هشتگ بزنین.',
#  'آزاد شده=)++++',
#  'اونقدری از این پدر و مادرا در عذابم که میخام زلیل بشن زلیل',
#  'دو',
#  'به امید آزادی برای روزی بهتر',
#  'برای',
#  'بچه ها هشتگ نیاد پایین تایم لاین من خیلی خلوته همه باهم ریتوییت، هشتگ',
#  'برای آرزوهای زنده ب گورمون',
#  'براي جلوگيري از ورود نيروهاي سركوبگر ريختن روغن سوخته در زمان ورودشون به خيابون ها ايده ي خوبيه ',
#  'این جمعه احتمال این که برید از احتمال اینکه بیاد خعیلی بیشتره.',
#  'برای همکارم متنِ سخنرانی امروز رو خوندم. بغض کرد و وقتی مشتری اومد تو موقع صحبت با مشتری بغضش ترکید. حرومزاده این شما.',
#  'آذری بالالاری، سیزی سسلنیر! قدرت خودمونو دست کم نگیریم!💪💪💪 جمهوری اسلامی صرفا و صرفا مامور از بین بردن ایران و ایرانی است. با همبستگی طوفان به پا می کنیم!',
#  'کاشکی مختار و یوسف پیامبر رو هم از آرشیو صدا و سیما پاک کنه. هرچند که با کشف حجاب و تطبیق جنسیت نباید پخشش کنن.',
#  'فریاد آزادی آزادی مردم در تهران. سخت نیس تو را از نو ساختن ایران❤️ ',
#  'این دفعه فرق میکنه',
#  'یواش خواهر',
#  'زن.زندگی.آزادی مرد.میهن آبادی',
#  'سرچ کنین ',
#  'مارا همه شب نمیبرد خواب',
#  'به امید روزهای خوب',
#  'خستگی معنا نداره❤️',
#  'خسته نباشی',
#  'برای ایران زیباییم',
#  'برای ایران',
#  'ما تنها نیستیم',
#  'دور نیست..',
#  'آخرین بغض ها🚶\u200d♂️🖤',
#  'برای شروین حاجیپور💪❤',
#  'کنار هم هستیم و میمونیم.',
#  'برای مخفف مهسا امینی',
#  'حرومزاده ها با پررویی هم میان گوه کاریاشون رو اعلام می کنن',
#  'صورت این گنجیشک رو با لگد خورد کردید و ترسیدید که روز تدفین کسی بیینه و عکس بگیره؟ برید واسه «دفن شبانه فاطمه زهرا» اشک بریزید. تف توی اون صورت گریونتون. ',
#  'در سقز ارتش مقابل سپاه قرار گرفت',
#  'اعتراضات در زادگاه مهسا(ژینا)، سقز شنبه ۱۶ مهر ۱۴۰۱ ',
#  'این درسته 👍😍👊',
#  'برای ژیناا',
#  'برای حسرت یک زندگی معمولی...... ',
#  'چهار',
#  'ما بیشماریم',
#  'برای حسین رونقی که صدای ما بود',
#  'من امروز فقط از یک چیز میترسم اگر الان نشه هرگز نمیشه پس ادامه میدیم',
#  'برای جوون هایی که هیچ وقت برنگشتن خونه',
#  'هشتمی',
#  'زن زندگی ازادی',
#  'امسال سال خونه حکومت اسلامی سرنگونه',
#  'ایرانی میمیرد، ذلت نمیپذیرد',
#  'امید که حال شما خوب باشه و خوب بمونه باید زنده بمونید.',
#  'داستان نخ نما و تکراری، برخورد سر با جسم سخت یا جسم سخت با سر، ریشتراش دزدیده شده، خطای انسانی ....',
#  'زن،زندگی،ازادی',
#  'حجاب چیه شماهارو بر میداریم',
#  'مهسای پرپرو توی گشت جنون ببین',
#  'اتحاد و همبستگی با استقامت و پایداری رمز پیروزی ست.',
#  'من مردم برای این همه قشنگی😍🤝🏻 ',
#  'پنجاه و هشت به امید ازادی',
#  'مراقب خودت باش خوش غیرت :)',
#  'چهار مهساامینی',
#  'ززن زندگی ازادی',
#  'نترسین نترسین،ماهمه با هم هستیم ده',
#  'هشتگ.یادتون.نره.جان.مادرتون.',
#  'آنکه با تفنگ آمده برای کشتن ما آمده است، می جنگیم، میمیریم، ذلت نمپذیریم.',
#  'حمله نیروهای امنیتی به دانشجویان دانشگاه شریف یکشنبه ۱۰ مهر ۱۴۰۱ ',
#  'بچه ها مقاومت',
#  'برای برای مردم ایران برای آزادی',
#  'برای اضطراب و نگرانی که برای عزیزانمون تو ایران داریم',
#  'هیچ کلمه ای برای توصیف این حکومت پیدا نمیکنم.حس میکنم دارم تو داستان میخونم یا دارم یخ کتابی میخونم که هر لحظه منتظرم به آخرش برسم ',
#  'هیچکس بعد رفتن توی پیج حمید رضا و دیدن عکس و فیلماش آدم سابق نشد :)',
#  'کم نیارید تا همین الانم بهترین بودیم تو کل تاریخ هرچی باشه ایرانی هستیم:))) 🔥 من باید برم مدرسه ولی وسطاش هشتگ میزارم قایمکی شمام ریتتوییت کنید! فایتینگگگگگ گانبارههههههههه',
#  'چقد خوشحالم که پسرای سرزمینمون انقد قوی و جسورن:) تو؟بدردنخور؟تو خواهر همه ی مایی و داری تلاشتو میکنی پس این حرفو به خودت نزن ما بهت افتخار میکنیم!',
#  'این جمعیت و میبینید کف خیابون ؟ هر کدومشون یه دنیا ارزو داشتن و دارن بیینید چه جوری جلوتون وایسادن و قید همه زندگیشون و زدن',
#  'شفاف سازی یسری دروغ های سایبری لطفا به هیچکس اعتماد نکنید ',
#  'برای آزادی',
#  'دیوس را بشناسید ✊',
#  'برای ایرانمون..#مهسا_امینی',
#  'برای منی که حرص میخورم برای اونایی که کشته شدن ولی هیچکاری نمیتونم بکنم جز هشتگ زدن',
#  'برای علی انصاریان که با بهونه کرونا به قتل رسید',
#  'حالا دیدید مشکل ما پسرا نبودیم',
#  'برای ۱۲ سالی که در زندانی به نام مدرسه گذشت',
#  'اگه به هر دلیلی نمیتونید اعتراض کنید حداقل اعتصاب کنید نمیشه که بشینید یه گوشه انتظار داشته باشید بقیه اوضاع رو برای شما درست کنند.',
#  'امروز میخوان موقع نماز جمعشون مردمو به جون هم بندازن اون تایم نرید بیرون مواظب خودتون باشین',
#  'تحریما فقط برای ماست',
#  'چندبار هی دارم میبینم مردم میگن چرا هشتگ میزنیم لایک و ریتوییت نمیخوره تروخدا لخاطر لایکو ریتوییت هشتگ نزنید بخاطر این بزنید که اصل قضیه دیده بشه دنبال اینچیزا نباشید',
#  'برای تهمینه یوسفی که پدر و برادرش رو صورتش اسید ریختن و شما هیچ وقت، هیچ کاری براش نکردید و اون از ایران فرار کرد',
#  'نه هنوز خيلي كند پيش ميره',
#  'آقا این همه دم از معرفت میزنید یکی جواب این سوال منو بده، من فالور ندارم هشتگ هام حسابه یا نه؟؟؟؟؟؟؟؟',
#  'صرفا جهت حساب شدن هشتگ ها',
#  'تعدادی در راهند، سعی میکنم تا شب کامل کنم',
#  'هرکجا هستیم یک قدم جلو بیاییم.',
#  'یه پزشکی پریروز میگفت یه مریض آخوند دارم که میشناسمش، امروز اومده بود مطبم با لباس مبدل. بهش گفتم خلع لباست کردن؟ گفت الان خطرناکه. اینا بلدن کی لباسشون در بیارن، تقیه و این حرفا رو هم که دارن',
#  'از این به بعد میتونین از کلمه(عرزشی) بعنوان یه فحش خارمادری استفاده کنید. با تشکر',
#  'امیدوارم حداقل دانش آموخته ها و دانشجویان علوم انسانی مناظره دکتر و در شبکه ۴ را دیده باشید.',
#  'خدا کنه دروغ باشه که نتو قطع میکنن',
#  'اخوند چقدر کم شده تو خیابون ، تخمشونو ملخ خورده انگار!!',
#  'خبری در راه است البته از سمت مردم ها',
#  'مرگ بر جمهوری اسلامی',
#  'دههه نودی هات رو فراخوندی؟ ببین دهه ۷۰ و ۸۰ ها چجوری تیکه تیکه ات میکنن',
#  'ب یاد مهسا',
#  'بیست و سه',
#  '246 برای آزادی ایران',
#  'به نظرم بهتره همه با خودشون آب و تنقلات انرژیزا و شیرین به همراه داشته باشن. متاسفانه نه زمان توقف و غذا خوردن هست و نه میشه به راحتی نفوذیا رو شناسایی کرد.',
#  'کون اخوند شماره سه',
#  '-فرمانده یگان مریوان کشته شد سرهنگ دو عبداللهی فرمانده یگان ویژه مریوان توسط یک سرباز به هلاکت رسید. ',
#  'ژینا جان هر کسی توی دنیا رسالتی داره🖤 She did her mission.',
#  'امسال سال خونه...',
#  'برای خیلی چیزها',
#  'بازار همه کاسبا خرابه جز آدم فروشا 😒',
#  'برای مهندسین الکترونیک یا کسانی که تو کار الکترونیک هستن ساختن شوکر برقی کاری نداره. یه کنترل تلویزیون با سایز مناسب لازمه',
#  'برای تک تک دانشجویانی که بازداشتشون کردید',
#  'امروز وارد کلاس درس مون شدیم که با این هشتگ های تایپ شده مواجه شدیم ! آخر سر نفهمیدیم کار کدوم یکی از بچه دبیرستانیا بود ولی هرکسی که بود دمش گرم...😊👌🏻🙃\U0001f972 ',
#  'صد و پنجاه و چهار',
#  '#مهسا_امینی 🖤🖤💔💔',
#  'همونم چس میگن اگر اخوندا بیان بگن الان روز مطمئن باشید که همون موقع شبه فراموش نمیکنم با بقیه ظام ها چه کنم؟',
#  'چهل و هفت',
#  'خواهرمو نبرید ما اینجا غریبیم..',
#  'شد ۱۲۳ میلیون.',
#  'ما همه کنار هم هستیم',
#  'یه گروه هکر دیگه پیداشون شده که اسمشون هستش :))',
#  'هلین احمدی بەدسته جلادانه ڕژیم ایران در میراوەی بوکان شەهید شد، Heleen Ahmadi was killed by regime force in the Kurdish city ',
#  'رسیدم مونترال موهامو میزنم!',
#  'آخ گفتی گفتی',
#  'زندگی',
#  ':)) شوهر خاله ها دوست داشتنین',
#  'این تیم بویی از ملی بودن نبرده. باید شعار امسالشون رو بذارن 《یک حکومت،یک تیم،بدون مردم》',
#  'برای روزی که خفه کردن اینا رو ببینم و از ته دلمخوشحال بشم',
#  'برای مهسا',
#  'چقدر چهره هاتون زشت و كريه ِ 🤮🤮#مهسا_امینی ',
#  'از کون دار زدنت هم برنامه ریزی دخترا و پسرای ایرانه',
#  'هشتکی که دریغ نشد',
#  'چشام میسوزه',
#  'برای کشته شده های رها شده در گورهای بی نام .. پدر ومادر هایی که هنوز چشم به راه گمشده هاشونن',
#  'بزنید خارشو بگویید اینا تک گیرتون بندازن میکشنتون',
#  'به امر شاهزاده بابت فراخوان سراسری به همه ثابت شد که کسی به این سادگیها نمیتونه این انقلاب رو تحریف یا مصادره کنه ، ولی باید طبق فرمایش شما باید حواسمون جمع باشه و هوشیار باقی بمونیم',
#  'الان موقش نیس روزی ک موفق بشیم خار همشونو میگائم',
#  'برای داغ دل ایران',
#  'مگه دوزارى تر از اين دافاى سرخاب سفيدابى جمهورى اسلامي وجود داره؟',
#  'همش میخوام ویروس اعمال کنم میترسم اون بنده خدا تازه اومده باشه از چیزی خبر نداشته باشه😭',
#  'برای سلاطین شیطانی ای که بهمون نسبت دادن😂',
#  'ریش هم میذاشت و همیشه صف اول نماز جمعه بود و مرگ بر آمریکا میگفت که از ایران بشه آمریکا بشنوه 😂😂😂😂',
#  'بخوان که شهر سرود زن شود ...',
#  'کیرماهم نیستی کیونی',
#  'برای نترسیدن',
#  'برای زلزلهزدگان کرمانشاه که هنوز آوره هستند و توی کانکس زنگی میکن',
#  'چه زیبا ',
#  'دو',
#  'صد سال سیاه نمیخوام این پلیسی که تو خیابان به جون مردم رحم نمیکنه ، حافظ جان و مال و ناموسم باشه !',
#  'شرکت در تظاهرات بزرگ با این پیام: "سیاست سکوت یک سیاست شیطانی است" تجمع در پارک استنتن واشنگتن حرکت بطرف کنگره آمریکا و خیابانهای DC Huge Oct 15, 22 Against the islamic republic regime of in support of in Washington DC ',
#  'اره',
#  'برای غم هامون برای دل هامون برای امیدمون برای آزادیمون',
#  'اَنونیموس : بزنی ، میخوری به قتل رسید 💔🖤',
#  'من دارم از دست میرم کمک',
#  'برای غیرتتون',
#  'فقط ۷ تای دیگه',
#  'آزادی',
#  'هفت',
#  'بچه ها من تازه اومدم توییتر بخاطر ایگنورم نکنید لطفا:) ممنون میشم فالو کنید یا ریتوئیت',
#  'خمینی',
#  'بوص 🤍کاری نکردم',
#  'یادتون باشه هشتگ خالی نزنید و یچیزی کنارش تایپ کنید',
#  'برای وقتی که یه تیپ خفن و گنگ میزدیم یه شال مینداختیم تر میخورد بهش!',
#  'بچه های رشت ترکوندن...دمشونگرم',
#  'فکر کنید تا پسفردا هشتگ صد میلیونی بشه:))',
#  'امروز سخت است، فردا سخت تر اما پس فردا آفتابی خواهد بود✌️',
#  'زنده باد باشرف مرد زنده باد شیر مادرت حلالت',
#  'برای آزادی',
#  'ایران : به روی تخم چشام 🤬🤬',
#  'بچه ها ماها که فالوورامون کمه فالو کنین که وسطه هشتگ زدنا فک نکنن رباتیم',
#  'ما همه مهساییم ما خسته نمیشیم',
#  'برای همه ما...',
#  '۳۶۰ .',
#  'بیرو دماغش شکست و دهنش پر خون شد تا خوشگل متوجه بشه مزه خون چجوریه…',
#  'لطفا فالو کنین تا به 100 برسم هشتگام حساب بشن (بک میدم زود)',
#  'تصویر انقلاب آپریل کره جنوبی با جمعیت میلیونی در خیابان های اصلی. ما باید مکان اصلی مان میدان آزادی باشد و تمام خیابان های اطراف. آزادی، برای زندگی، برای مهسا و نیکاهایمان. ✌️ ',
#  'برای ایرانم',
#  'دلیل رفتن جاذبه خارج نیست نه ، علت دافعه داخله 🖤🖤🖤 ',
#  'برای آزادی وطنم',
#  'برای مهسا…',
#  'مرد ميهن آبادي ',
#  '-برای ازادی🕊️',
#  'این فیکه بچه ها مواظب باشید! ',
#  'قربون دهه هشتادیا بشم شما کی اینقد بزرگ شدین اخه بهتون افتخار میکنم حیف شما حیف جوونی شما :((((',
#  'مهسا امینی',
#  'چقدر موافقم برای آزادی',
#  'برای خون هایی که ریختند',
#  'برای مهسا امینی',
#  '"زندە باد الاحواز" : "بژی بژی الاحواز" از جملە شعارهای پر از همبستگی بود کە بلوک هزاران نفری کوردها در کنار "بژی بژی کوردستان" و بە اهتزاز در آوردن آگاهانە پرچم در برلین سردادند، چیزی کە جریان موجسوار از شنیدنش آشفتە خواهند شد. ',
#  'اعتراضها در استان مازندرن و درگیری نیروهای امنیتی و معترضان. چهارشنبه ۳۰ شهریور ۱۴۰۱ ',
#  'برای اینکه غم بزرگ رو به خشم بزرگ تبدیل کردیم',
#  'انیناموس خداسسسسس😂🚶🏻\u200d♂️ ',
#  'برای مادرم ایران',
#  'بیست و یک برای آزادی',
#  'تادحایی ک بتونیم هشتگ میزنیم',
#  'هموطن همسایه دوست مهمان عزیز ❤️',
#  'کاش همه اینجوری باشیم❤',
#  'این زیبا بود',
#  'کاشکی جای باتوم میشد بسیجیا رو بزنیم سرِ نیزه:))) ',
#  'نهمین',
#  'بچه ها همه می شنوند ، ',
#  'دمت گرم حتمابا راننده خوب حساب کردی اونم کرایه ازت نگرفته میگن آدم خوش معامله حساب مال مردمه همینه آورین آورین',
#  'دوستان کسی توئیت منو میبینه؟ نمیدونم چرا توئیتر آنالیز توئیتهامو نشون نمیده، نمیفهمم چقدر ایمپرشن دارم. ولی هر توئیتی با هشتگ که ببینم ریت میزنم. ولی هیچ کدوم از توئیتهام ریت نمیخوره.',
#  'برای',
#  'دور چشت بگردم خواهرم:))',
#  'همه باید بهم بپیوندند🥺🙏',
#  'بچه ها فالوم کنید هشتگ هام حساب شه',
#  'متحد شوید مردم این بار نه نامش اعتراض است و نه تجمع و نه تظاهرات مسالمت آمیز. نام این اتفاق و رویداد "#انقلاب" است.',
#  'هشتصد و هفت',
#  'دورتون بگردم این وقته شب',
#  'برای یکی شدن',
#  'دست هر کسی رو که برای آزادی مردممون جونشون رو کف دستشون گذاشتن میبوسم این حد از شجاعت و اتحاد بیسابقه بوده',
#  'برای خواهرم',
#  'به وقت آزادی!',
#  'برای بچه های ایران',
#  'وحشیای کثافت دارن سعی میکنن مارو بد نشون بدن',
#  'عه چه آشنا دختره احیاناً مشکلات قلبی نداشت تو فیلم؟!',
#  'برای مهسا زندگی ۱۰ زن',
#  'چقدر رذلین واقعا. منت جانی که نگرفتین رو به سرمون میذارین؟',
#  'روحش شاد',
#  'برای من جون که تنها دل خوشیم با رفیقم کافه رفتنو سیگار کشیدنه!',
#  'برای برادرت',
#  'براي اميد تو دلمون',
#  'همه بهت افتخار ميكنيم زيبا :(',
#  'دیگه قضیه فقط مهسا نیس شما باید برای خون خیلیا جواب پس بدین برای اونا چی دارین بگین',
#  'این کاربر به زودی خبر آزادی ایران را از آیت صفحه اعلام می کند... سوم آذر ',
#  'الان ترامپ بود دهنشون سرویس بود حیف که ایت الله بایدن هس',
#  'اینو باید به اینترنشنال گفت که دم به دقیقه داره خبر میذاره .بدون هشتگ!انقدر سخته؟',
#  'برای همه ی سالهایی که توی صف ایستادیم که مو ،ناخن و ابروهامون رو چک کنن!',
#  'صدای باشید هموطنان کرد در کنار شما هستم',
#  'برای',
#  'تروخدا هر چیزی رو باور نکنید. تروخدا هر چیزی رو باور نکنید. تروخدا هر چیزی رو باور نکنید. تروخدا هر چیزی رو باور نکنید. تروخدا هر چیزی رو باور نکنید. تروخدا هر چیزی رو باور نکنید.',
#  'دو',
#  'برای ایران :)))) (31)',
#  'بشمار صد و پنجاه و هشت',
#  'برای دختران وطنم',
#  'آمین',
#  'دستاتو میبوسم من ادامه بده',
#  'قرار نیست کسی از مارو بگیرن که به این جاها بخواد برسه... یعنی نمیذاریم که کسیو بگیرن ۲۴،۲۵،۲۶ آبان ✌🏻🕊️',
#  'شبکه سه رو هک کردن واقعا؟',
#  'برای تمام دختر و پسرایی که ۴۰ ساله کاری کردین فک کن دشمن همدیگن',
#  'درده خالصه',
#  'آخرین چسنالم و بکنم و دیگه تموم! بچه هایی که شهید شدن برای یکی انقدر مهم بودن که ازشون فیلم گرفتن ،خواستم بگم من و اگر کشتن همینم ندارم :) همگی فایتینگ قوی ادامه بدید ✌️',
#  'برای ارمیتا ۶۲',
#  'برای ایران آزاد 🕊',
#  'نفرتمون چی؟',
#  'ملت دارند مشق میکنند این جریانات پیروی است باشد ک اعتراضات از چهارسال به سالی یک بار و چه بسا چندماه و به اذن خدا هر روزه شود تا سرنگونی ریشه ظلم و ستم ک با نام خدا و دین چهل و چهار سال جنایت و دزدی کردند',
#  'اگر سربازی و نمیتونی بیای تو خیابون کنار مردمت بجاش نزنشون و سعی کن فراریشون بدی و کمکشون کنی',
#  'قهرمان ها',
#  'دریغ است ایران که ویران شود کنام پلنگان و شیران شود',
#  'ادامه میدیم',
#  'کم نیارین برای ایران',
#  'آقای خامنهای دهههاست که حتی مصاحبه نکرده و توسط یک خبرنگار (حتی داخلی!) به چالش کشیده نشده. با چندین و چند خَدَم و حَشَم تشریف میارند و سخنرانی میکنند و میروند. نمردیم و معنی اقتدار را فهمیدیم! :))))',
#  'بخاطر سیو های اینستام که هیچوقت به مرحله ی خرید نرسیدن',
#  ' وقتی شده پرونده جمع. آزادی از قفس تنگ. اینکه از همه پند... بگیرم طرف حق... بکنم واسهی وطنم جنگ. پافشاری تا سر حد مرگ.',
#  'اينو وصل كنه ديگه تمومه ',
#  'زنده باد آزادی',
#  'ببین دمت گرم که هشتگ میزنی، ولی مثل اینکه هشتگ خالی بزنیم نتیجه عکس داره. هر چیزی میخوای بنویس بعدش هشتگ بزن، شده حتی یه کلمه، مثلا اسامی مسافرای پرواز اوکراین.',
#  'برق با اب جریان نمیگیره..؟',
#  'اوه اوه چه وحشتی کردن بدبخت های اصولگرا و اصلاح طلب از حامد اسماعیلیون از وقتی گفت احتمال داره بیانیه دعوت به راهپیمایی انبوه در تهران بده شلوارتان رو گوهی کردید',
#  'مردم را میکشند که بگویند و بفهمانند که در کلاس اموزشی درشرایطی ایده ال بدون ضرب وشتم فوت کرده است ',
#  'کیر خوندین :))))',
#  'برای خلاص شدن از این وضعیت مریض و رسیدن به چیزی که میخواییم و براش داریم تلاش میکنیم.',
#  'داریم میرسیم به ۵۵:)',
#  'براى آزادي',
#  'برای شهیدان شهرم که جونشون رو کف دستشون گذاشتن برای آزادی همه ی ما و آیندگانمون',
#  'اره بابا من که سیاسی نیستم',
#  'هنوز نت دارم پس',
#  '۹۰',
#  'امروز یکم خوبه',
#  'همین الان شاهد بودم یه دخترو بردن توکوچه با باتوم زدن تو صورتش تا می تونید زنای ارزشی رو کتک بزنید،دلتون نسوزه',
#  'بچهها دمتون گرم نذارید هشتگ ها از جون بیوفته ✌️✌️✌️ برای آبان ۹۸ که گرفتینم و شکنجهم دادین ...',
#  'من برای همه و همه برای یکی',
#  'برای تمام آزادی های سرکوب شده',
#  'پنجاه و نه و نیم',
#  'حاضر براي و و مرام',
#  'روحش شاد و یادش گرامی باد',
#  'بیاید مهره مار بخونیم عشق تو دروغ بود دیگه نه دیگه نه من نه تو دیگه',
#  'خاک به سرم من تازه اومدم توئیتر داشنم از توئیتر در حد گاوه 😬',
#  'برای',
#  'چهار',
#  'بچهها این عرزشی رو ریپورت بلاک کنید! چک کردم دیدم رو با ال میزنه که از ترند خارج بشه! لطفا ریتوئیت کنید دیده بشه. ',
#  'مادر تک تکشونو به چوب حراج میزنیم',
#  'بمیرم من براشون',
#  'برای ایران',
#  'مردم دارن یواش بواش متوجه میشن ریشه همه مصیبت ها شماهایید.',
#  'من رفتم سرکار و اومدم و دوباره قویتر شروع کردم :)',
#  'شنبه با بالاییه اومدید سرکوب، یه روزی از همین روزا با این پایینیه لاشتون رو از کف خیابون جمع میکنیم! ',
#  'براییییی آزادی',
#  'براي ازادي ايران اشك و خون ميريزيم',
#  'روحش شاد انتقامشو میگیریم',
#  'ما برای پس گرفتن ازادیمون پا پس نمیکشیم و میجنگیم',
#  'ما هنوز بیداریم عوضیا داریم توییت میزنیم برا کوری چشمتون !',
#  'ظلم پایدار نیست ',
#  'برای بسته های معیشتی که هربار بیشتر میبایست جمع بشه، برای لباس کهنه هایی که هربار بیشتر درخواست میشد',
#  'برای ایرانمون',
#  'به امید رهایی',
#  'که زده بودن، دو باااار. برای 1ون 19 ثانیه ی ترسناک',
#  'برای جادی و علم بی اندازهش',
#  'برای آزادی وطنم',
#  'همایت همراه شو عزیز این درد این مبارزه مشترک است آزادی حق شماست',
#  'بیایید یه قولی به خودمون بدیم، اول این عکس هایی که شر میکنم رو ببینید، بعدم هر سایبری که داره گند میزنه به جنبش ما و افکار عمومی رو داره عوض میکنه بلاک کنیم، بوس به همتون 😘 (لطفا ریتوییت کنید) ',
#  'همه مردم ایران رمز پیروزی ما در برابر دشمن خارجیه',
#  'صب میشه این شب…',
#  'بد ریدین دوستان ',
#  'برای مردم',
#  'برای ازادی',
#  'سال ها بعد در کتاب های تاریخ: انقلاب اکتبر ایران؟!',
#  'بخاطر عمرجوانی که بیهوده تلف شد...',
#  'ای خدا یار من آنجاست حواست باشد او نشان کردة اینجاست حواست باشد',
#  'چشم',
#  'گل گفتی رفیق❤',
#  'صدای این بچه ها تو کف خیابونِ 💪 وقتی همه باهم باشیم چنان قدرتی پیدا میکنیم که تو چندروز به هدف خواهیم رسید',
#  'شش',
#  'تو 22 سالگی کی فکرشو میکنه بکشنش تو مملکت خودش اونم حاکمیت خودش... ',
#  'برای علیرضا فیروزجا که فراریش دادین',
#  'ده ده',
#  'شهریار جان خوشحال شدم که آزاد شدی. ما هم مصمم تر از قبل به همراه تو به انقلاب ادامه میدهیم.👊🏼',
#  'سپاس از روشنگری شما بانو دکتر رویا عبدی گرامی',
#  'برای ازادی',
#  'برای مهسا ، برای ما',
#  'زن زندگی آزادی!',
#  'برای آزادی',
#  'چقدر این تصویر زیبا، با دنیایی از رنج، پایداری و در نهایت امیده حامد اسماعیلیون ',
#  "تهران، مقابل متروی دروازه دولت شنبه ۱۶ مهر، ساعت ۱۷' ",
#  'چنین اعتصاب فراگیر و گسترده ای تا به امروز بی سابقه بوده؛ رویترز اعتصابات امروز را منجر به بحران مشروعیت نظام تلقی می کند.',
#  'برای وطن برای مهسا خواهرم',
#  'حالا رییس علی خاطرش از نبود مردان دلیر مکدر نیست ، رییس و فرمانده از دلوار تا رشت بیدار است ، قشون اجنبی فهمیده است که کشتی هایش مثل کشتی های پرتغالیها در خلیج فارس به گل خواهد نشست ...',
#  'ده داداش دو برابر پیشنهادت زدم میشه منو فاللو کنی من هیچ فالووری ندارم',
#  'آنها را به بیرون فروشگاه هدایت کنید، همچنین با نصب انواع نوشتههای تبلیغاتی و هشدار دهنده در ورودی و داخل فروشگاه اقدام کنید.》 "Because in iran آزادی داره"',
#  'حرکت گفت به اینا رحم کنین نزنین اونو دوبار بزنین آخه به اینا میشه رحم کرد...',
#  'کیرم تو میهن',
#  'اتک دیده هاش :)',
#  'بخاطر حنانه کیا دختر شهید نوشهری ',
#  'برای حق✌',
#  'اونا که زر مفته ما میدونیم ؛) ولی اگه ۸۸، ۲۹ساله بوده الان ۴۴ نمیشه!',
#  'برای مهسا',
#  'یک',
#  'رمز پیروزی ما یکی شدن و یک دست شدن کل کشور و تمام اقوام عزیزمونه! دست همدیگر را رها نکنیم! ',
#  'به امید آزادی',
#  'اینها هنوز معنی واقعی اسلام رو درک نکردند.',
#  'میدون صومعهسرا (گیلان) دیشب تظاهرات بود صبح مادرا پدرا جلو کلانتری بودن الان فرمانده سپاه با کلی بسیجی و اطلاعاتی های لباس شخصی کمپ زدن وسط میدون خدا بخیر کنه',
#  'دوستان حس میکنم هشتگام حساب نمیشن کمک کنین پس',
#  'حتی برای یه پیاده روی ساده و بدون استرس از ترس خفت شدن',
#  'تو حوزه تکنولوژی واقعا جادی هم خبره و شریفه. وجود امثال این شخص برای دنیای آزاد ضروریه.',
#  'برای شروین که تو حبسه ❤️',
#  'برای التماس های از سر عجزم',
#  'چقد غمانگیر',
#  'تا کی به قربانگاه دادن نوجوانها ؟!',
#  'برای ایرانم',
#  'مرسییییی عزیز دلم',
#  'برای آزادی',
#  'درود مهسای عزیزم ',
#  'شرمندگی خانواده ها یه طرف دست و پا زدن و نرسیدن ماهم یه طرف',
#  'اینا اگه خایه خیابون داشتن زیر لباساشون پنهون نمیشدن رو صندلی شعار نمیدادن',
#  'این روزا نه دلم میخواد کار کنم، نه بیکار باشم نه دلم میخواد از ایران برم نه دوست دارم بمونم، نه دلم میخواد برم خونه نه تو خیابون باشم. شبا نه دلم میخواد بخوابم نه بیدار بمونم، نه دوست دارم تنها باشم نه میلی به کسی دارم... و در "نمیدونم چمه ترین" حالتم!',
#  'یه روز خوب میاد...',
#  'بسرای تا که هستی که سرودن است بودن به ترنمی دژ وحشت این دیار بشکن….',
#  'برای شهیدامون',
#  'بخاطر این دوتا که هیچ وقت صداوسیما پخششون نکرد ',
#  'کی گفته',
#  'برای خندهای خفه شدمون',
#  'برای ازادی',
#  'ما رو از اعدام نترسان... ',
#  'گفتند که چنینیم و چنانیم دریغا این ها همه لالایی خواباندن ما بود',
#  'حیف تو وطنم گیر کیا افتادی فدات بشم',
#  'بزرگی تو یه کلیپ بیست ثانیه ای:',
#  'متن کم اوردم دیگه 😂',
#  'برای آزادی',
#  'همه باهممم',
#  'برای',
#  'ما همه مهساییم ما خسته نمیشیم',
#  '❌❌❌لطفا اطلاع رسانی کنید❌❌❌',
#  'برای برای برای',
#  'برای آزادی',
#  'زن ،زندگی ، آزادی',
#  'از ربات به ربات صداتو دارم فالوت هم کردم',
#  'همون همیشگی ۲۱',
#  'هجده',
#  'لعنت به همشون',
#  'از اپ Tor استفاده کنید',
#  'پنجاه؟تا هشتاد میلیونیش نکنیم سرمو راحت رو بالش نمیزارم',
#  'آمبولانس نباید سالم در بره، کادر بیمارستان باید بدونه تو این ایام جونش دست خودشه، چاره ای نیست تر و خشک باید باهم بسوزن در غیر این صورت هیچ بازداشتی زنده برنمیگرده برای مردم زجر کشیده ی ایران...',
#  'عرق پهلوی خوردید مست کردید ریختید تو خیابون حالا ما باید تگریتونو جمع کنیم عن مستای۵۷ \u2067',
#  'برای نکا ایران…',
#  'انسان ایرانی جدید',
#  'اگه این توییتو می خونی 2 تا دونه کامنت و هشتگ بزار، 5 دقیقه هم زمان نمیبره\U0001fae4',
#  'اعتراضات دیگه به سر قیمت دلار نیست',
#  'دمش گرم 😍',
#  'یک',
#  'نمیدونم چقدر صحت داره ولی میدونم مغز یه سریارو باز کردن ریدن وسطش اگه همچین چیزی بخواد حتی به زور هم اعمال کنه باید بدونه ما مردم تحریمش میکنیم. ',
#  'بگذرد این روزگار تلخ تر از زهر',
#  'به امید محاکمه همه ی این مفسد ها',
#  'تیم ملی فوتبال مگه مال ایران نیست ؟ خب ما نمیخوایم امسال برید و بازی کنید. چون طبق برنامه بازی ها اون تایمی که شما بازی دارید ما کف خیابون هستیم.',
#  'لطفا همه بلند شین لطفا همه بلند شین لطفا همه بلند شین لطفا همه بلند شین لطفا همه بلند شین لطفا همه بلند شین لطفا همه بلند شین',
#  'شما مجبورید هر شب با ما مبارزه کنید و ما فقط یک شب پیروز میشیم.',
#  'سر راهتون همدیگه رو فالو کنید',
#  'برای ایران',
#  'برای گاریای که اصلاحطلب و اصولگرا را بهش میبندیم.',
#  'خونهایی که در این ریخته میشه، پاکترین و مقدس ترین خونهاست و دژخیمانی که این خونهای پاک را میریزند، اهریمنیترین اهریمنان هستند.',
#  'به قول مادربزرگم اگه بیل بلدی بزنی یه بیلی به کون خودت بزن….',
#  'برای دل پدربزرگا و مادربزرگای که نوه/هاشون رو توی گوشی میزنن و حسرت لمس کردنشون رو دارن',
#  'تولد دوباره هممون مبارک',
#  '"بچه ها چند شب پیش تو تهران یه سری معمورا دخرا و خانم ها رو لخت ک دن بهشون خندیدن، این بود اسلامی که خودتون رو براش میکشتید؟" خودم: آقا نهایت بیشرفی و بی ناموسیه که تو بیای به اسم اسلام این کارو بکنی',
#  'خدا داری میبینی؟! یا تورم گرفتن؟!',
#  'خودتونو برسونید دانشگاه شریف دانشجوهامونو محاصره کردن جون بچه هامون در خطره',
#  'همه باهم هستیم',
#  'ما پشت همیم💚🤍❤️',
#  'برای آزادیِ ایرانِ کهن',
#  'من اصلا رپ دوست نداشتم، از وقتی رو دیدم ، به رپ علاقه پیدا کردم.#توماج_صالحی_راآزادکنید.',
#  'برای آزادی',
#  'براي نابودي جمهوري اسلامي',
#  'ته این اعتراضات اگه پیروزی مردم نباشه ترسناکه. برای همین لطفا کم نیارین. کاش ایران بودم که منم بیام بیرون. به جاش دارم هرچقد که میتونم از اینجا پا میزنم. لطفا قوی بمونید. ❤️',
#  'توپ تانک فشفشه آخوند باید گم بشه به امید آزادی ',
#  'حس میکنم مردم خسته میشن ولی اگه اینبار نشه... پس بیاین کم نیاریم! با وجود خستگی ،مشغله، ... من زیاد صدام به کسی نمیرسه ولی سعیمو میکنم شما که میرسه هم سعیتونو بکنین. "یا الان یا هیچوقت"',
#  'منی که میدونم احتمال زیاد حساب نمیشن...',
#  'به یاد مهسا',
#  'دمشون گرمم',
#  'برای',
#  'برای آزادی',
#  'شبانه روز ادامه میدیم تا برسیم به پیروزی',
#  'چهار',
#  'برای مهسا',
#  'کم نشدهههههههههه',
#  'خب حالا که فهمیدید خودتون گورتونو گم کنید',
#  'میپرسید این اعتراضات رهبر نداره ؟ دوستان رهبر همیشه نباید زنده باشه ، چه رهبری حقیقی تر و زیباتر از که سکوت مارو به طغیان تبدیل کرد .',
#  'برای غیرت مردم ایران',
#  'هشتمی',
#  'یک مهسا امینی دیگر به قتل رسید. اینبار نامش بود.',
#  'زن_زندگی_آزادی سی صد و پانزده',
#  'برای آزادی',
#  'خسته خسته خسته با انگیزه',
#  'هر چی باید همه حسرت بکشن،ما کشیدیم که!',
#  'هشتگ بزنیم',
#  'یادتون نره از هشتگ هم استفاده کنید. برای خواهرم',
#  'فردا سالروز اولین نسل کشی هزاره ها در افغانستان است همزمان با هشتگ هشتگ را فراموش نکنیم به یاد مهساهای افغانستان و ایران ',
#  'یعنی اگه با چشای خودم نمیدیدم باور نمیکردم این کسخلا هنوز وجود داشته باشن! به نام آزادی به نام',
#  'از کجا شروع کنیم',
#  'آنانیموس ، بگاشون',
#  'لطفا قوی باشین نزارین مثل آبان ۹۸ بشه ایندفعه فرق میکنه ایندفعه باید برنده شیم',
#  'به هر حال ۳۲',
#  'ترس معنی نداره',
#  'برای ایران',
#  'شمارش هشتگ ',
#  'آبان همیشه خونین',
#  'منشن هفت',
#  'فضای تظاهرات امروز ملبورن وصف نشدنی هست ۲۲ اکتبر ۲۰۲۲ ',
#  'تو جاهایی که راه درو داره جمع شین اینطوری قیچی میشین',
#  'از اینم بیشتر میشه',
#  'بچه ها منم ویروسی کنید عمو ببینه',
#  'برای مهسا شروع کردیم برای نیکا ادامه میدیم🕊 ',
#  'بدیهیست ما هموطن شما و اون تیم حکومتی نیستیم. ما ایرانی هستیم نه میوه بازار مشترک لبنان و سوریه و روسیه و انگلیس و چین. شما بطول تاریخ بیشرفید. ملت ایران از سپاه بیریشه و ارتش بیغیرت تیر میخورد!',
#  'بنظر کارش با کتمان تموم نمیشه بنظر کارش با عدم رضایت مردم انجام نمیشه بنظر در خواب خرگوشی بسر میبری',
#  'ژن ژیان آزادی ',
#  'الان خیلیا کف خیابون دارن از جونشون مایه میزارن برای کشورشون :)',
#  'چقدره زیبا *.*',
#  'برای اسم مهسا امینی که جهانی شد و تمام تلاش های سایبری عرزشی های وطن فروشِ آدمکش را پایمال کرد. هرچقدر هشتگ اشتباه مهسا ایمنی و اسم اشتباه دیگری بزنید از قدرت کم نخواهد کرد. فردا این موقع به ۱۰۰ میلیون خواهد رسید. بترسید، بترسید (( ما )) همه باهم هستیم.',
#  'در اینجوری جنایت میکنن و عادل فردوسی پور هنوز ساکته! حیف این همه حمایتی که از برنامه ۹۰ کردیم…',
#  'آهای کارمند ، کاسب ، کارگر ، .... وقتش رسیده که یه بار برای همیشه دست از غر زدن بر داری ، مشتتو گره کنی ، دو روز کار و پول و حتی معاش رو تعطیل کن ، حقتو بگیر این سرزمین هنوزم اینقدر منابع و فرصت پیشرفت داره که همه جمعیت ایران ازش بهرمند شن .',
#  'برای خواهرم و آزادی ایران',
#  ': باد هیچ موقع خاک نمیشه اینو هیشکی بهت یاد نمیده خون با هیچی پاک نمیشه اینو هیشکی بهت یاد نمیده',
#  'بلک لیست مردم',
#  'از سفر آمده بود',
#  'برای این اتحاد قشنگ',
#  'یک',
#  'برای',
#  'اینم سکته نکرد، سکتونده شد!',
#  'امیدوارم راحت نمیری!!',
#  'برای همه اون هایی که راهیو انتخاب کردن و براش تلاش کردند مثل خودت🌹✌️ ژن ژیان ئازادی',
#  'برای این اقتصاد دستوری .',
#  'نگاه کنید شهر لیمان خاکی که پوتین ضمیمه کرد به روسیه را چطوری بسادگی سرباز اوکراینی پس گرفت و شاد،پوتین را عقب زدند.روزگارآخوندو پوتین سیاهه ورق برگشته. بجنبید جوانان در خیابانها این مدلی شادی کنید و بجنگید و عقب برانید. ',
#  'بچه ها یه کمک کوچیک تا صدتایی که هشتگ ها بهتر دیده شه',
#  'هوا چقدر خوبه',
#  'این هشتگ اشتباهه باید با اندرلاین باشه',
#  'برای همه ترسایی که تو جونمون انداختن',
#  'واسه ندا که بیگناه و بود کشتنش',
#  'دوازده',
#  'فقط ایران',
#  'نود درصد',
#  'چشم',
#  'رمز پیروزی',
#  'نود',
#  'ب امید ازادی',
#  'بی خاین',
#  'دَه',
#  'برای هربار ورود و خروج از کشور که کلی استرس و ترس داشتیم',
#  'برم اینستا بیام منشن استار را میندازم',
#  'سی و هشت',
#  'در شرایطی چنین بحرانی معنی اتفاق بلوچستان چیزی جز تهدید به ایجاد زمین سوخته است؟ و آیا فکر نمیکنید این تهدید تا یه جایی کارسازه',
#  'برای ایران',
#  'این حسو من سه هفتس دارم، ترکیبی از امید، غم ترس غرور',
#  'برای برادرا و خواهرام',
#  'کاظممم؟؟؟؟تو بیا لایو ما باهات انگلیسی حرف بزنیم تو هم انگلیسی جواب بده ببینیم اصلا بلدی حرف بزنی بعد درباره اینکه چه گهی خوردی اعصاب خودمونو خورد می کنیم ،بیا بیا همین الان بیا',
#  'برای همه روز هایی که ترسیدیم خودمون باشیم صدای موزیک و کم کردیم روسری و جلو کشیدیم.. برای همه ی حسرت های روزهای جوونی تو مملکت خودمون..',
#  'برای مهاجرت های اجباری',
#  'خفه شو بابا با مردم باش ریدم به رهبری که تو نظام کثیف فعلی پولدار شده چشمش به خارج و کانادای خودشه اصلا تو چه انی هستی از طرف مردم حرف میزنی تخم داری بیا بیرون هشتگت معلومه کی هستی تو از کوچه گذر کن به خیابان بریز',
#  'تهدید گوهر عشقی مادر شهید ستار بهشتی توسط ج.ا اگر اتفاقی برای خودم و خانواه ام بیفته، مسئولیت آن بعهده خامنه ای خواهد بود.',
#  'Anonymous اعتراضات ایران رو برده تو لوله متریکس. باریک.',
#  'مرگ بر جمهوری اسلامی به امید آزادی✌️✌️❤️',
#  'مراقب خودتون باشید',
#  'دست به دست تا سرنگونی',
#  'برای اون نخ قرمز مقنعه دبیرستانم که ناظم بزور دوخت که موهام معلوم نباشه و من تا اخر سال با همون نخ قرمز مقنعمو سر کردم.',
#  'مهسا',
#  'مریم کعبی(مریم قربانی) صاحب کافه مری شیرین معصومی (خواهر رامین معصومی) مصطفی پاوندی میترا صالحیان پور ملیکا صالحیان پور فاطمه خلفی زاده کاظم ناصرمطوری مرتضی ابراهیمی مقدم کریم ابراهیمی مقدم پیمان باوندی امیر گرناوی حسین سیدوای',
#  'چه قلب شکستها 💙 ',
#  'برای آزادی برای میهن برای زن برای ایران',
#  '۱۴۰۰ سال عقب ماندگی، چیزی نیست که قابل جبران باشه. جناب لجن',
#  'سایه مراقب خودت باش عزیزم',
#  'برای مهسا',
#  'برای ایران',
#  'گریه کن بسیجی، این تازه سرشه.',
#  'یه عمر مردم سیستان و بلوچستان رو تو فقر و گرسنگی نگه داشتن٬ امیدوارم همین سیستان و بلوچستان جرتون بدن',
#  'دیگه ترس مردم از حجاب سر نکردن در شهر ریخته تا ازادی اما فاصله زیاده',
#  'بچه ها لطفا یه متن بنویسیم برای یکشنبه و هممون رو روی اون متن هشتگ بزنیم و اطلاع رسانی کنیم که ما همچین کارهایی نمیکنیم با قران، مسجد و.. تا بفهمن همه که تقصیر ما نیست لطفا ینفر یه متن انگلیسی بنویسه و به بقیه هم بده تا توییت کنیمم',
#  'نمیزاریم حسین ماهینی و شروین هم تبدیل به هشتگ بشن',
#  'مردم شهربابک لطف کنید بلند شید واسه اعتراضات سیرجان بلند شده شماها فقط روزه سکوت گرفتید😐#شهربابک سی و چهار',
#  'برای نام زیبای مادرم که زن بود و زندگی بخشید ولی آزاد نبود بردن اسمش در فرم استخدام.',
#  'برای سلامتی همتون بچه ها',
#  'برای آزادی بیانی که نیست و رسانه ی ازاد نداریم',
#  'نذارید از ترند خارج شه',
#  'زندگی جای دیگری نیست یارومیل. زندگی همینجاست! میان اشک و سرب',
#  'برای خواب معصومانه ی عشق',
#  'شما یه نگاه به این زن کن چندش اوره توی پادگان نظامی هم بره همه فرار میکنن',
#  'هیفده',
#  'هشتگ زدن رو ادامه بدید ازادی از ان ماست همه باهم برای ایران آزاد از چنگال این حرام زادگان هفت پدر',
#  'یازده ، برای سپیده رشنو',
#  'پس ادامه میدیم',
#  'برای ازادی',
#  'یعنی واقعا با حادثه اوین انقدر همچی ساکت شد؟ بیخیال... گول جنگ روانی حرومزاده هارو نخورید تا میتونید اطلاع رسانی کنید اخبار و تا میتونید بریزید بیرون که هرچند الان اعتصاب تاثیر صدبرابری داره.',
#  'طرز تهیه رو بگید براتون درست کنیم خیلی ها تو خونه نشستن و نمیدونن چیکار کنن که کمک باشه',
#  'پیروزی ما قطعی هست ما کشورمون رو پس میگیریم.',
#  'ساعت ۴ بعدازظهر روز ۳۱ شهریور زیر پل پارک وی فقط نگاهشون کردم با خشم و جستوجو برای پیدا کردن نشونهای که بگه میتونن از ما و کنار ما باشن و اونا بیخیال… بستنی یخی و آبمیوه میخوردن که توان کافی برای زدن ما رو داشته باشن ',
#  'فدای اون موهای سفید قشنگت بشم',
#  'جلوی بچه ها به مادرشون تیر زدند ',
#  'چهار',
#  'برای حال خوب برای شادی',
#  'چون فقط خانواده خودش رو ميبينه فكر ميكنه همه مثل خودشونن...',
#  'بقیشو نمیبینید ✌🏻 ',
#  'زنشو صیغه میکنم مثل پیامبرتون',
#  'هشتگ ۱۰ هم فراموش نکنید',
#  'چهار',
#  'مهسا',
#  'برای آزادی ',
#  'ما جاییایم که آسمون هست ولی واسه پرواز شده بالمون بسته',
#  'مادرجندهها تو خونشون و روز تولدش حجابش این بوده سگبگاد تکتکتون رو',
#  'برای ترویج فساد و دروغ',
#  'وفردای ازادی هیچ چیز رافراموش نخواهیم کرد. نون خورهای ج.ا. از صدا و سیما گرفته تا اون بالا مالاها...',
#  'برای پدرهایی که دستشان خالی بود و چشمانشان پر.',
#  'برای آزادی',
#  'برای',
#  'وای',
#  'استوری فارسی شاهان گوکباکار (رجب اودیک) ',
#  'به خاطر مردم شجاع و قویمون',
#  'هیچوقت هم اسم این جاکش مسلکها رو نتونستم درست بخونم، ابرآوران؟ ابرآروان؟ برآبروان؟',
#  'فالو کردم:) بک میدی اکانت منم دیده بشه🙂',
#  'چهار',
#  'برای آزادی',
#  'برای مهسا',
#  'این بده که😐 ',
#  'نه دشمن دراین بوم و بر لانه داشت نه بیگانه جایی در این خانه داشت از آنروز دشمن بما چیره گشت که ما را روان و خرد تیره گشت از آنروز این خانه ویرانه شد که نان آورش مرد بیگانه شد چو ناکس به ده کدخدایی کند کشاورز باید گدایی کند 1/2',
#  'بیست و هشت',
#  'بفرستیم برای آدمای مختلف، کامنت کنیم و نمیدونم، فکر کنم توی توییتر جا نمیشه. یکی بهم بگه لیمیت توییتر چقدره و این متن چقدر طولانیه، مرتبش کنیم دوباره و توییت کنید تا میتونید. هشتگها رو هم هرطور که ترنده تغییر بدیم.',
#  'فالورام کمه حساب نمیشه 😭',
#  'برای پیروزی',
#  'براي غواصان جوان عمليات فريب! كربلاي ٤ كه برادران عراقيتون با دست بسته زنده زنده خاكشون كردند. عملياتي كه لو رفته بود ولي جوان هاي ايراني رو عمدا فرستادند جلو.',
#  'همه باهم برای ایران🤍',
#  'برای بلوچها',
#  'همین که هشتکا بره بالا کافیه اصلا هیچکس منو نبینه',
#  'مهسا هرگز تنها نخواهد ماند',
#  'اخوند همان آخوندک است',
#  'این خیلی خوبه دانشگاه الزهرا تظاهرات اونجا دو گل محسوب میشه زمین میزبانه😁',
#  'ارتش باید بیاد به کمک مردم#مهسا_امینی',
#  'تجمع اعتراضی یکم اکتبر ۲۰۲۲ در مرکز شهر وین اتریش پ.ن: برای احترام به حقوق اخلاقی اشخاص روی ویدیو فیلتر اعمال شده. ',
#  'امینی',
#  'دمت گرم. همه ی تلاشمونو میکنیم که بی نتیجه نمونه.',
#  'نه این وری نه اون وری. میریم به بیت رهبری. … آره دیگه، اونم بهمون چسبیده.',
#  'برای ژینا',
#  'دمت گرم مَرد',
#  'برای همهی خشمهایی که تو ما انباشته شده',
#  'اواین توییت امشب تقدیم به که عاشق ماهی سیاه کوچولو بود. فرزاد شهید راه آگاهی شد و هنوزم خانوادش نمیدونن کجا دفن شده.',
#  'ای وای ...ای وای....',
#  'حسین رونقی نشونمون داد چطوری نترسیم :) اونجا که وسط مصاحبه گفت "ایراد نداره"',
#  'میریم واسه ۸۰ میلیووووووون :)',
#  "برای بغض هامون وقتی به این پیام برمیخوریم «this item isn't available in your country»",
#  'کاشکی اون و میبستم',
#  'برای ، خانواده بزرگ ایران .',
#  'این سیس ، سیس یه ایرانیه به خدا ک ایرانی دارن بینشون',
#  'زنده باد',
#  'به کیرم به کیرم دیشب تو خواب هلال ماهو دیدم',
#  'سبز میشم دوبارە💚',
#  'منشن میزاریییم',
#  'هرچی میتونین هشتگ بزنین',
#  'من گلو درد ام نمیتونم گریه کنم بچه دو ساله ام اشک هامو ببینه',
#  'ولی من عاشققق متحد شدنمونم دختر و پسر مرد و زن کرد و ترک فارس و لر نوجوون و جوون و مسن خواهش میکنم کم نیارید ادامه بدید🤍\U0001f972 به امید آزادی',
#  'به زودی باید برن تو همون استادیوم با اشک چشم سرود خدافظ فرمانده رو بخونن',
#  'هنوز باورم نمیشه شروین رو گرفتن...',
#  ...]

# %% [markdown]
# # 1. One hot encoding

# %%
# 1. find one hot encoding of each word for each year
# 2. find 10 nearest words from "ولنتاین"


new_result = []
for text in result :
  new_result.append(text.split(" "))

category = set()

for li in new_result :
  for text in li :
    category.add(text)
print(len(category))

category = list(category)

oneHot = np.zeros((len(category),len(category)))

oneHotdic = {}

for i in range(len(category)) :
      oneHot[i,i] = 1
      oneHotdic[category[i]] = torch.tensor(oneHot[i]).float()



find_k_nearest_neighbors(word,oneHotdic,k)
# Out:
# 32116
# ['زندگی',
#  'کوچیکی',
#  'آخر',
#  'خانوادشون',
#  'ابنجا',
#  'بجای',
#  'کرد:)..#OpIran',
#  'ترینن',
#  'حرامزادهگان',
#  'ادامه']

# %% [markdown]
# # 2. TF-IDF

# %%
# 1. find the TF-IDF of all tweets.
# 2. choose one tweets randomly.
# 3. find 10 nearest tweets from chosen tweet.


tf = np.zeros((len(new_result),len(category)))


count = {}

all = 0

for tweet in new_result :
  for word in tweet :
    all += 1
    count[word] = 0

for tweet in new_result :
  for word in tweet :
    count[word] += 1

# saving index of each word in category for reducing Time order
indexWord = {}
for index,word in enumerate(category) :
  indexWord[word] = index 

# fill numpy array :
for i,tweet in enumerate(new_result) :
  
  for word in tweet :
    
    cnt = 0
    for new_word in tweet :
      if new_word == word :
        cnt +=1
    tf[i,indexWord[word]] = float(cnt)/len(tweet) * math.log(float(all)/count[word])
  

resultDict = {}

for index,tweet in enumerate(result) :
  resultDict[tweet] = torch.tensor(tf[index])
resultDict

find_k_nearest_neighbors(result[11],resultDict,k)
# Out:
# ['برای آزادی ایران تا آخرین قطره خونم میجنگم 🇮🇷✌🏻 (7) ',
#  'تا آخرین قطره اینترنت',
#  'تا آخرین قطره ی خون',
#  'برای مردمم میجنگم',
#  'برای آزادی ایران',
#  'من امشب خونم رو برای وطنم خواهم داد هر قطره خون من فدای آزادی میهنم',
#  'برای آزادی ',
#  'برای ایران ',
#  'برای ایران برای آزادی',
#  'تا آزادی']

# %% [markdown]
# # 3. Word2Vec

# %%
# 1. train a word2vec model base on all tweets for each year.
# 2. find 10 nearest words from "ولنتاین"
#category

model = Word2Vec(sentences = new_result)

model.wv.most_similar("آزادی")
# Out:
# [('ازادی', 0.9874179363250732),
#  ('زن', 0.9833468794822693),
#  ('زندگی،', 0.9817682504653931),
#  ('امید', 0.9769082069396973),
#  ('ایران', 0.9757297039031982),
#  ('خواهرم', 0.9737299680709839),
#  ('زندگی', 0.9733548164367676),
#  ('زن،', 0.9687106609344482),
#  ('،زندگی', 0.96824711561203),
#  ('برای', 0.9667270183563232)]

# %% [markdown]
# # 4. Contextualized embedding

# %%
# 1. fine tune a bert model base on all tweets for each year.
# 2. find 10 nearest words from "آزادی"

# %% [markdown]
# # Pros and Cons :
#
# ## One-hot vector :
#
# advantages:
#
#  One-hot encoding easily processed by machine learning models because it is easy to implement and have simple structure.
#
#
#  One-hot encoding preserves the original meaning of categorical features and makes them more interpretable for humans.
#
# disadvantages:
#
# One-hot encoding can result in a significant increase in the number of features, which can lead to computational challenges and overfitting.
#
# If embedding of one-hot vector done in a large data set, result matrix can be very large and use lot of memory.
#
#
# ## TF-IDF:
#
# advantages:
#
# can help capture the semantic meaning of words.
#
# TF-IDF reduce the number of common words such as "the" and "a" ,which can help reduce their impact on the model.
#
#
# TF-IDF is widely used in information retrieval systems such as search engines to rank documents based on their relevance to a query.
#
# disadvantages:
#
# TF-IDF does not capture the order or context of words in a document, which can lead to reduce undrestanding of context.
#
# TF-IDF operates at the word-level and does not capture the meaning of phrases or sentences,
#
#
# ## Word2Vec:
#
# advantages:
#
# word2vec can capture the relationships between words, such as synonyms, antonyms, which can improve the performance of many NLP tasks.
#
# Word2Vec generates vector representations of words, which can be used as features in machine learning models for text classification, sentiment analysis, and other tasks.
#
# disadvantages:
#
# Training a Word2Vec model can be computationally expensive, especially with large datasets and high-dimensional vector representations.
#
# Word2Vec operates at the word-level and does not capture the meaning of phrases or sentences, which can limit its effectiveness in tasks such as sentiment analysis or text generation.
#
# ## Contextualized embeddings:
#
#
# advantages:
#
# Contextualized embeddings are designed to capture the meaning of a word based on the context in which it appears, which can improve the performance of many natural language processing tasks.
#
# Contextualized embeddings have been shown to improve the performance of many natural language processing tasks, such as sentiment analysis, named entity recognition, and machine translation.
#
# disadvantages:
#
# Training and using contextualized embeddings can be computationally expensive, especially with large datasets and high-dimensional vector representations.
#
# As contextualized embedding designed for complex relations between words in context,they hard to examine and interpret.
